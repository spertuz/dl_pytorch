# %% [markdown]
# # Configuration

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ## Linear regression
# In this notebook, we will fit a model of the form:
# $$
# h_w(x)=w_0 + w_1 x
# $$

# %%
W0 = 1.0
W1 = 2.0
N = 100
np.random.seed(42)
x = np.random.rand(N, 1)
e = 0.1*np.random.rand(N, 1)
y = W0 + W1*x + e
plt.scatter(x, y)

# %% [markdown]
# Split randomly into training and validation

# %%
idx = np.arange(N)
np.random.shuffle(idx)
i_train = idx[0:int(0.8*N)]
i_test = idx[int(0.8*N):]
x_train, y_train = x[i_train], y[i_train]
x_test, y_test = x[i_test], y[i_test]
plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test)
